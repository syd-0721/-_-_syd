# %% [markdown]
# <a href="https://colab.research.google.com/github/syd-0721/-_-_syd/blob/python%E7%A8%8B%E5%BA%8F%E8%AE%BE%E8%AE%A1/%E7%AC%AC%E4%B8%80%E6%AC%A1%E4%BD%9C%E4%B8%9A%E7%AC%AC%E4%B8%80%E9%A2%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#第一次作业第一题
'''
数学表达式
'''
x = (pow(2,4)+7-3*4)/5
y = (1+pow(3,2))*(16%7)/7
print(x)
print(y)
# Out:
# 2.2
# 2.857142857142857
